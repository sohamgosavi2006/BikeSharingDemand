# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Dataset Link -> https://www.kaggle.com/datasets/yasserh/bike-sharing-dataset

# %%
# @title 1.) Boom Bikes Data Analysis

# %%
#To access files from Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importing Dataset for Mobile Health Human Behaviour Analysis
file_path = '/content/drive/MyDrive/Colab Notebooks/1Stop AIML/ML Dataset/BoomBikes.csv'
dataset = pd.read_csv(file_path)

dataset
# Out:
# Mounted at /content/drive
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
# ...

# %%
# To get mean,min value for columns
dataset.describe()

# 25% → A value where one-quarter of the data is smaller
# 50% → The middle value (half the data is smaller and other half is bigger)
# Three-quarters (75%) of the numbers are smaller than this.
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
dataset.info()
# To get data about non-null count, datatype for  columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
# Procedure -> Converting Numerical values of column table to String

# Assigning 'string'(name of season) values to different seasons instead of numeric values

# 1 -> Spring , 2 -> Summer , 3 -> Fall , 4 -> Winter
# .loc[] is used to select data by labels (row labels and column names).
dataset.loc[(dataset['season'] == 1), 'season'] = 'Spring'
dataset.loc[(dataset['season'] == 2), 'season'] = 'Summer'
dataset.loc[(dataset['season'] == 3), 'season'] = 'Fall'
dataset.loc[(dataset['season'] == 4), 'season'] = 'Winter'

# 0 -> 2018 , 1 -> 2019 (735 rows = 365 + 365 days)
dataset.loc[(dataset['yr'] == 0), 'yr'] = 2018
dataset.loc[(dataset['yr'] == 1), 'yr'] = 2019

# %%
dataset['season'].astype('category').value_counts()
# Out:
# season
# Fall      188
# Summer    184
# Spring    180
# Winter    178
# Name: count, dtype: int64

# %%
# Assigning string values to month [name of month] instead of numerical values

# dataset.loc[(dataset['mnth'] == 1), 'mnth'] == 'JAN'

# Creating using function
# 'x' is panda series from 1 to 12
def object_map_months(x):
  return x.map({1 : "JAN" , 2: "FEB",3 : "MAR" , 4: "APR",5 : "MAY" , 6: "JUN",
                7 : "JUL" , 8: "AUG",9 : "SEP" , 10: "OCT",11 : "NOV" , 12: "DEC"})

# Applying Function to Data
dataset[['mnth']] = dataset[['mnth']].apply(object_map_months);

# %%
# Checking updated data for months
dataset['mnth'].astype('category').value_counts()
# Out:
# mnth
# AUG    62
# DEC    62
# JUL    62
# JAN    62
# OCT    62
# MAY    62
# MAR    62
# APR    60
# NOV    60
# JUN    60
# SEP    60
# FEB    56
# Name: count, dtype: int64

# %%
# Assigning values [numerial to string] for Weekdays
def object_map_weekdays(x):
  return x.map({0 : "SUN", 1 : "MON" , 2: "TUE", 3 : "WED" , 4: "THU",5 : "FRI" , 6: "SAT"})

dataset[['weekday']] = dataset[['weekday']].apply(object_map_weekdays)

# %%
# Checking if values is equally distributed for days of week for entire dataset
dataset['weekday'].astype('category').value_counts()
# Out:
# weekday
# MON    105
# SAT    105
# SUN    105
# FRI    104
# THU    104
# TUE    104
# WED    103
# Name: count, dtype: int64

# %%
# For Weather -
# 1-> Clear , 2-> Mist , 3-> Rain

dataset.loc[(dataset['weathersit'] == 1), 'weathersit'] = 'Clear'
dataset.loc[(dataset['weathersit'] == 2), 'weathersit'] = 'Mist'
dataset.loc[(dataset['weathersit'] == 3), 'weathersit'] = 'Rain'

# %%
# To show first 7 rows
dataset.head(7)
# Out:
#    instant      dteday  season    yr mnth  holiday weekday  workingday  \
# 0        1  01-01-2018  Spring  2018  JAN        0     SAT           0
# 1        2  02-01-2018  Spring  2018  JAN        0     SUN           0
# 2        3  03-01-2018  Spring  2018  JAN        0     MON           1
# 3        4  04-01-2018  Spring  2018  JAN        0     TUE           1
# 4        5  05-01-2018  Spring  2018  JAN        0     WED           1
# 5        6  06-01-2018  Spring  2018  JAN        0     THU           1
# 6        7  07-01-2018  Spring  2018  JAN        0     FRI           1
#
#   weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0       Mist  14.110847  18.18125  80.5833  10.749882     331         654
# 1       Mist  14.902598  17.68695  69.6087  16.652113     131         670
# 2      Clear   8.050924   9.47025  43.7273  16.636703     120        1229
# 3      Clear   8.200000  10.60610  59.0435  10.739832     108        1454
# ...

# %%
# @title 2.) DATA VISUALISATION

# %%
# Importing Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bike Rentals Types->
# a.) casual : For daily or one place to another biking service
# b.) registered : Biking Service rented for 1 week , 1 month
# c.) cnt (total count) = casual + registered

# Weather ->
# temp : Measured Temperature , atemp : Actual Temperature (Feels Like Temperature)

# %%
# For Temperature

# Area Under Curve = 1 , A smooth curve is drawn [(KDE) Kernal Density Estimate] to show shape in which data is distributed ,
#                        draws bars to show how different temperature ranges appear in the data
#                         (here in btw 10-15 degree is most occured in the entire 2 years)
# Here, Density tells you what fraction of all values are in each range, so the total area of the bars = 1.
sns.distplot(dataset['temp'])
# Out:
# <Axes: xlabel='temp', ylabel='Density'>

# %%
# Here most occurred temp is btw (30 - 35 degree)
sns.distplot(dataset['atemp'])
# Out:
# <Axes: xlabel='atemp', ylabel='Density'>

# %%
# Wind Speed

sns.distplot(dataset['windspeed'])
# Out:
# <Axes: xlabel='windspeed', ylabel='Density'>

# %%
# Target Variables -> Count of total rental bikes [casual + registered bikes]

# Around 4500 bikes per day is the highest orders received
sns.distplot(dataset['cnt'])
# Out:
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
# Converting Date to DateTime Format -

# type is set to 'datetime64[ns]' for precision where 'ns' is nanosecond and used for precision to avoid loss of data
dataset['dteday'] = dataset['dteday'].astype('datetime64[ns]')

dataset_categorical = dataset.select_dtypes(exclude = ['float64' , 'datetime64[ns]' , 'int64'])
dataset_categorical
# Out:
#      season mnth weekday weathersit
# 0    Spring  JAN     SAT       Mist
# 1    Spring  JAN     SUN       Mist
# 2    Spring  JAN     MON      Clear
# 3    Spring  JAN     TUE      Clear
# 4    Spring  JAN     WED      Clear
# ..      ...  ...     ...        ...
# 725  Spring  DEC     THU       Mist
# 726  Spring  DEC     FRI       Mist
# 727  Spring  DEC     SAT       Mist
# 728  Spring  DEC     SUN      Clear
# 729  Spring  DEC     MON       Mist
#
# [730 rows x 4 columns]

# %%
# Using Box Plot
plt.figure(figsize=(20,20))

plt.subplot(3,3,1)
sns.boxplot(x='season',y='cnt',data=dataset)
plt.subplot(3,3,2)
sns.boxplot(x='mnth',y='cnt',data=dataset)

plt.subplot(3,3,3)
sns.boxplot(x='weekday',y='cnt',data=dataset)
plt.subplot(3,3,4)
sns.boxplot(x='weathersit',y='cnt',data=dataset)

plt.subplot(3,3,5)
sns.boxplot(x='workingday',y='cnt',data=dataset)
plt.subplot(3,3,6)
sns.boxplot(x='yr',y='cnt',data=dataset)
plt.subplot(3,3,7)
sns.boxplot(x='holiday',y='cnt',data=dataset)

plt.show()

# %%
intVarList = ['casual' , 'registered' , 'cnt' ]

# Loops through column of dataset and changes column's type to float64
for var in intVarList:
  dataset[var] = dataset[var].astype('float64')

# Saves into new dataset which contain only float
dataset_numeric = dataset.select_dtypes(include = ['float64'])
dataset_numeric.head()
# Out:
#         temp     atemp      hum  windspeed  casual  registered     cnt
# 0  14.110847  18.18125  80.5833  10.749882   331.0       654.0   985.0
# 1  14.902598  17.68695  69.6087  16.652113   131.0       670.0   801.0
# 2   8.050924   9.47025  43.7273  16.636703   120.0      1229.0  1349.0
# 3   8.200000  10.60610  59.0435  10.739832   108.0      1454.0  1562.0
# 4   9.305237  11.46350  43.6957  12.522300    82.0      1518.0  1600.0

# %%
# A big grid of scatter plots shows the relationship between every pair of numeric columns in our numeric dataset

# Identification In Scatter Plot ->
# 1. Positive correlation (both go up together)
# In the scatter plots, the dots slope upward from left to right.
# Example: temp vs atemp — as one increases, the other increases.

# 2. Negative correlation (one goes up, the other goes down)
# Dots slope downward from left to right.
# Example: temp vs humidity — hotter days might have lower humidity.

# 3. No correlation (random spread)
# Dots are scattered with no clear slope.
# Means the variables don’t affect each other much.

sns.pairplot(dataset_numeric)

# %%
# Creating Co Relational Matrix -
# It shows how strongly different columns in our dataset are related to each other
# Each cell in table has number between -1 to +1 where,
# +1 → perfect positive relationship (if one goes up, the other always goes up)
# -1 → perfect negative relationship (if one goes up, the other always goes down [moves opposite to each other])
# Value around 0 has Weak Correlation (no similarity)

corr = dataset_numeric.corr()
corr
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.991696  0.128565  -0.158186  0.542731    0.539436
# atemp       0.991696  1.000000  0.141512  -0.183876  0.543362    0.543678
# hum         0.128565  0.141512  1.000000  -0.248506 -0.075211   -0.089212
# windspeed  -0.158186 -0.183876 -0.248506   1.000000 -0.167995   -0.217914
# casual      0.542731  0.543362 -0.075211  -0.167995  1.000000    0.394137
# registered  0.539436  0.543678 -0.089212  -0.217914  0.394137    1.000000
# cnt         0.627044  0.630685 -0.098543  -0.235132  0.672123    0.945411
#
#                  cnt
# temp        0.627044
# atemp       0.630685
# hum        -0.098543
# windspeed  -0.235132
# casual      0.672123
# registered  0.945411
# cnt         1.000000

# %%
# Creating HeatMap ->

mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig,ax = plt.subplots()
fig.set_size_inches(10,10)
sns.heatmap(corr,mask=mask,vmax=1,square=True,annot=True)
# Out:
# <Axes: >

# %%
# We would REMOVE atemp(actual temperature) to avoid repititionas as it is highly
# corelated with temp which means it is nearly giving the same result as temp
# eg -> temp =30 and atemp =29.8

dataset.drop('atemp',axis=1,inplace=True)
dataset.head()
# Out:
#    instant     dteday  season    yr mnth  holiday weekday  workingday  \
# 0        1 2018-01-01  Spring  2018  JAN        0     SAT           0
# 1        2 2018-02-01  Spring  2018  JAN        0     SUN           0
# 2        3 2018-03-01  Spring  2018  JAN        0     MON           1
# 3        4 2018-04-01  Spring  2018  JAN        0     TUE           1
# 4        5 2018-05-01  Spring  2018  JAN        0     WED           1
#
#   weathersit       temp      hum  windspeed  casual  registered     cnt
# 0       Mist  14.110847  80.5833  10.749882   331.0       654.0   985.0
# 1       Mist  14.902598  69.6087  16.652113   131.0       670.0   801.0
# 2      Clear   8.050924  43.7273  16.636703   120.0      1229.0  1349.0
# 3      Clear   8.200000  59.0435  10.739832   108.0      1454.0  1562.0
# 4      Clear   9.305237  43.6957  12.522300    82.0      1518.0  1600.0

# %%
# @title 3.) DATA PREPARATION

# %%
dataset_categorical = dataset.select_dtypes(include = ['object'])
dataset_categorical.head()
# Out:
#    season mnth weekday weathersit
# 0  Spring  JAN     SAT       Mist
# 1  Spring  JAN     SUN       Mist
# 2  Spring  JAN     MON      Clear
# 3  Spring  JAN     TUE      Clear
# 4  Spring  JAN     WED      Clear

# %%
# Creating DUMMY DATA [Dummy Variables]

# Concept ->
# You take one original column (eg -> Season)
# Each new dummy column[spring,summer,winter] asks a yes/no question w.r.t Seasons column
# "Is this row's Season Winter?" → If yes, put 1, if no, put 0.
# "Is this row's Season Summer?" → If yes, put 1, if no, put 0.

# It helps to convert categorical columns into a format that a machine learning model can understand (1-> True , 0 -> False)
dataset_dummies = pd.get_dummies(dataset_categorical,drop_first=True)
dataset_dummies.head()
# Out:
#    season_Spring  season_Summer  season_Winter  mnth_AUG  mnth_DEC  mnth_FEB  \
# 0           True          False          False     False     False     False
# 1           True          False          False     False     False     False
# 2           True          False          False     False     False     False
# 3           True          False          False     False     False     False
# 4           True          False          False     False     False     False
#
#    mnth_JAN  mnth_JUL  mnth_JUN  mnth_MAR  ...  mnth_OCT  mnth_SEP  \
# 0      True     False     False     False  ...     False     False
# 1      True     False     False     False  ...     False     False
# 2      True     False     False     False  ...     False     False
# 3      True     False     False     False  ...     False     False
# 4      True     False     False     False  ...     False     False
#
#    weekday_MON  weekday_SAT  weekday_SUN  weekday_THU  weekday_TUE  \
# ...

# %%
# Drop Categorical variable columns : removing season, month, weekday, weather column
dataset = dataset.drop(list(dataset_categorical.columns),axis=1)
dataset.head()
# Out:
#    instant     dteday    yr  holiday  workingday       temp      hum  \
# 0        1 2018-01-01  2018        0           0  14.110847  80.5833
# 1        2 2018-02-01  2018        0           0  14.902598  69.6087
# 2        3 2018-03-01  2018        0           1   8.050924  43.7273
# 3        4 2018-04-01  2018        0           1   8.200000  59.0435
# 4        5 2018-05-01  2018        0           1   9.305237  43.6957
#
#    windspeed  casual  registered     cnt
# 0  10.749882   331.0       654.0   985.0
# 1  16.652113   131.0       670.0   801.0
# 2  16.636703   120.0      1229.0  1349.0
# 3  10.739832   108.0      1454.0  1562.0
# 4  12.522300    82.0      1518.0  1600.0

# %%
# Now Concatenate Dummy Variables with the Dataset

# axis = 1 -> In pandas means operate along Columns
dataset = pd.concat([dataset,dataset_dummies],axis=1)

# To train the model better and for more accuracy, it is necessary to remove unwanted data
# Dropping extra information (yr column is already present so no need to include date-month-day column)
dataset = dataset.drop(['instant', 'dteday'] , axis =1)
dataset.head()
# Out:
#      yr  holiday  workingday       temp      hum  windspeed  casual  \
# 0  2018        0           0  14.110847  80.5833  10.749882   331.0
# 1  2018        0           0  14.902598  69.6087  16.652113   131.0
# 2  2018        0           1   8.050924  43.7273  16.636703   120.0
# 3  2018        0           1   8.200000  59.0435  10.739832   108.0
# 4  2018        0           1   9.305237  43.6957  12.522300    82.0
#
#    registered     cnt  season_Spring  ...  mnth_OCT  mnth_SEP  weekday_MON  \
# 0       654.0   985.0           True  ...     False     False        False
# 1       670.0   801.0           True  ...     False     False        False
# 2      1229.0  1349.0           True  ...     False     False         True
# 3      1454.0  1562.0           True  ...     False     False        False
# 4      1518.0  1600.0           True  ...     False     False        False
#
#    weekday_SAT  weekday_SUN  weekday_THU  weekday_TUE  weekday_WED  \
# ...

# %%
# @title 4.) MODEL BUILDING AND EVALUATION

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# Rows are shuffled and splitted into ->
# df_train → the training data (70% of the rows)
# df_test → the testing data (30% of the rows)

# Training data → used by the model to learn patterns.
# Testing data → used after training to check how well the model performs on data it hasn’t seen before.

# Split the Dataframe into Train and Test Dataset
from sklearn.model_selection import train_test_split
np.random.seed(0)

# Spliting data into Training data and Testing data
# random_state will fix the shuffled rows and every time we run code, same split is followed and
# on removing random_state, the rows picked for training/testing may change every run, making results harder to compare.
df_train, df_test = train_test_split(dataset, train_size = 0.7, test_size = 0.3, random_state = 100)

df_train
# Out:
#        yr  holiday  workingday       temp      hum  windspeed  casual  \
# 653  2019        0           1  19.201653  55.8333  12.208807   922.0
# 576  2019        0           1  29.246653  70.4167  11.083475   968.0
# 426  2019        0           0  16.980847  62.1250  10.792293   956.0
# 728  2019        0           0  10.489153  48.3333  23.500518   364.0
# 482  2019        0           0  15.443347  48.9583   8.708325  1120.0
# ..    ...      ...         ...        ...      ...        ...     ...
# 526  2019        0           1  29.554153  58.7917  13.916771  1017.0
# 578  2019        0           1  30.852500  65.9583   8.666718   983.0
# 53   2018        0           1   9.091299  42.3043   6.305571   139.0
# 350  2018        0           0  10.591653  56.0833  16.292189   275.0
# 79   2018        0           1  17.647835  73.7391  19.348461   401.0
#
#      registered     cnt  season_Spring  ...  mnth_OCT  mnth_SEP  weekday_MON  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Many machine learning models (like KNN, neural networks) work better when all features are on the same scale.
# scaled value = (value - min)/(max - min) [after scaling all values are between 0 to 1 scale range]

# Apply scaler to all columns except Dummy Variables [ only 0/1 value (yes/no) ]
var = ["temp" , "hum" , "windspeed" , "casual" , "registered" , "cnt"]
df_train[var] = scaler.fit_transform(df_train[var])
df_train.head()
# Out:
#        yr  holiday  workingday      temp       hum  windspeed    casual  \
# 653  2019        0           1  0.509887  0.575354   0.300794  0.280402
# 576  2019        0           1  0.815169  0.725633   0.264686  0.294422
# 426  2019        0           0  0.442393  0.640189   0.255342  0.290765
# 728  2019        0           0  0.245101  0.498067   0.663106  0.110332
# 482  2019        0           0  0.395666  0.504508   0.188475  0.340750
#
#      registered       cnt  season_Spring  ...  mnth_OCT  mnth_SEP  \
# 653    0.951776  0.864243          False  ...      True     False
# 576    0.899220  0.827658          False  ...     False     False
# 426    0.446145  0.465255           True  ...     False     False
# 728    0.203869  0.204096           True  ...     False     False
# 482    0.444701  0.482973          False  ...     False     False
#
#      weekday_MON  weekday_SAT  weekday_SUN  weekday_THU  weekday_TUE  \
# ...

# %%
# To check corelation coefficient to see which variables (two) are highly similar to each other
plt.figure(figsize=(25,25))
sns.heatmap(df_train.corr(),annot=True,cmap ="YlGnBu")
plt.show()

# %%
# X → Our features (input variables)
# This is the data the model uses to make predictions
# Example: temperature, humidity, windspeed

# y → Your target (output variable) [it is what we are trying to predict]
# This is what we want the model to predict
# Example: bike rental count (cnt)

# Regenerating df_train from the original dataset before popping 'cnt'
df_train, df_test = train_test_split(dataset, train_size = 0.7, test_size = 0.3, random_state = 100)
var = ["temp" , "hum" , "windspeed" , "casual" , "registered" , "cnt"]
scaler = MinMaxScaler()
df_train[var] = scaler.fit_transform(df_train[var])

y_train = df_train.pop('cnt')
X_train = df_train.drop(['casual' , 'registered'], axis = 1)


# Convert boolean (True/False) columns to integers
for col in X_train.columns:
    if X_train[col].dtype == 'bool':
        X_train[col] = X_train[col].astype(int)

X_train.head()
# Out:
#        yr  holiday  workingday      temp       hum  windspeed  season_Spring  \
# 653  2019        0           1  0.509887  0.575354   0.300794              0
# 576  2019        0           1  0.815169  0.725633   0.264686              0
# 426  2019        0           0  0.442393  0.640189   0.255342              1
# 728  2019        0           0  0.245101  0.498067   0.663106              1
# 482  2019        0           0  0.395666  0.504508   0.188475              0
#
#      season_Summer  season_Winter  mnth_AUG  ...  mnth_OCT  mnth_SEP  \
# 653              0              1         0  ...         1         0
# 576              0              0         0  ...         0         0
# 426              0              0         0  ...         0         0
# 728              0              0         0  ...         0         0
# 482              1              0         0  ...         0         0
#
#      weekday_MON  weekday_SAT  weekday_SUN  weekday_THU  weekday_TUE  \
# ...

# %%
np.array(X_train)
# Out:
# array([[2.019e+03, 0.000e+00, 1.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [2.019e+03, 0.000e+00, 1.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [2.019e+03, 0.000e+00, 0.000e+00, ..., 0.000e+00, 1.000e+00,
#         0.000e+00],
#        ...,
#        [2.018e+03, 0.000e+00, 1.000e+00, ..., 1.000e+00, 0.000e+00,
#         0.000e+00],
#        [2.018e+03, 0.000e+00, 0.000e+00, ..., 0.000e+00, 1.000e+00,
#         0.000e+00],
#        [2.018e+03, 0.000e+00, 1.000e+00, ..., 0.000e+00, 1.000e+00,
#         0.000e+00]])

# %%
import statsmodels.api as sm

# Adds a column of 1’s to our training data so the regression can calculate the
# intercept (the point where the line crosses the Y-axis) or else it would pass through origin
X_train_lm = sm.add_constant(X_train)

# OLS -> Ordinary Least Squares [Method to find best fitting line through Data]
lr = sm.OLS(y_train, X_train_lm).fit()
lr.params

# Example ->

# const         50.2
# temp          20.3
# hum           -5.1

# Intercept = 50.2
# For every 1° increase in temp, prediction increases by +20.3 (keeping other data(hum) constant)
# Out:
# const             -374.482535
# yr                   0.232116
# holiday            -93.671946
# workingday         -93.585021
# temp                 0.450562
# hum                 -0.151340
# windspeed           -0.186453
# season_Spring       -0.048159
# season_Summer        0.038725
# season_Winter        0.105847
# mnth_AUG             0.014404
# mnth_DEC            -0.045586
# mnth_FEB            -0.032282
# mnth_JAN            -0.062777
# mnth_JUL            -0.040350
# mnth_JUN            -0.002972
# mnth_MAR             0.001045
# mnth_MAY             0.023940
# mnth_NOV            -0.041851
# mnth_OCT             0.007534
# mnth_SEP             0.081060
# weekday_MON         -0.020907
# weekday_SAT        -93.585516
# weekday_SUN        -93.640052
# weekday_THU         -0.009237
# weekday_TUE         -0.018890
# weekday_WED         -0.005388
# weathersit_Mist     -0.061066
# weathersit_Rain     -0.257443
# dtype: float64

# %%
# Creating Linear Regression

# Linear regression in ML is one of the simplest algorithms used to predict a value based on other values.

# We draw a straight line through our data points so that the line is as close as possible to all points and
# That line can then be used to make predictions

lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
print(lm.intercept_)
# Out:
# [ 0.23211572 -0.0513123   0.03561284  0.45056169 -0.15134004 -0.18645332
#  -0.04815901  0.03872462  0.10584692  0.01440398 -0.0455859  -0.03228181
#  -0.06277659 -0.04035007 -0.00297239  0.00104515  0.02393995 -0.04185131
#   0.00753359  0.0810599  -0.02090673  0.03511753 -0.01941807 -0.00923674
#  -0.01888985 -0.00538751 -0.0610664  -0.25744279]
# -468.1031685875367

# %%
# If R - value comes 1 (error in model)
# R-squared = 0.853 → our model explains 85% of the changes in bike rentals and other 15% is due
# to other factors which our model cannot predict
lr.summary()

# R-squared (R²):
# It tells you how much of the changes in your target (y) can be explained by your model’s inputs (X).

# R² = 1 (or 100%) → Your guesses match perfectly.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     103.8
# Date:                Thu, 21 Aug 2025   Prob (F-statistic):          8.74e-182
# Time:                        17:17:52   Log-Likelihood:                 527.95
# No. Observations:                 510   AIC:                            -999.9
# Df Residuals:                     482   BIC:                            -881.3
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# Using Recursive Feature Elimination (RFE)
from sklearn.feature_selection import RFE

# RFE will help train the model by removing the least important features

lm = LinearRegression()
# Tells RFE to find 15 best features from
# Estimator is the model RFE will use to decide which features are important (here LinearRegression Model is used)
rfe1 = RFE(estimator=lm, n_features_to_select=15)

# Fitting with 15 best features
rfe1.fit(X_train,y_train)

print(rfe1.ranking_)
print(rfe1.support_)
# Out:
# [ 1  1  1  1  1  1  1  1  1  6  3  4  1  1 13 14  5  2 10  1  8  1  7 11
#   9 12  1  1]
# [ True  True  True  True  True  True  True  True  True False False False
#   True  True False False False False False  True False  True False False
#  False False  True  True]

# %%
# Printing best 15 Features according to Linear Regression Model from dataset column
col1 = X_train.columns[rfe1.support_]
col1
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed',
#        'season_Spring', 'season_Summer', 'season_Winter', 'mnth_JAN',
#        'mnth_JUL', 'mnth_SEP', 'weekday_SAT', 'weathersit_Mist',
#        'weathersit_Rain'],
#       dtype='object')

# %%
X_train_rfe1 = X_train[col1]

X_train_lm = sm.add_constant(X_train_rfe1)
lm1 = sm.OLS(y_train, X_train_lm).fit()
lm1.summary()

# Adj. R-squared value has dropped by 0.1 percent only from the previous measurement where we had more 14 columns
# This shows that out model is performing good by optimising resources provided to producing accurate result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     184.6
# Date:                Thu, 21 Aug 2025   Prob (F-statistic):          2.31e-191
# Time:                        17:17:52   Log-Likelihood:                 519.88
# No. Observations:                 510   AIC:                            -1008.
# Df Residuals:                     494   BIC:                            -940.0
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF -> VIF = 1 : No Overlap , 5 > VIF > 1 : Some Overlap , VIF > 5 : High Overlap
# It tells us how much one feature (column) is overlapping / correlated
# with other features in the dataset.

# Purpose of VIF -> If two features (temp and atemp) are almost the same, the model gets confused hence
#                   VIF helps detect and remove duplicate features for model optimisation


vif = pd.DataFrame()
vif['features'] = X_train_rfe1.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe1.values, i) for i in range(X_train_rfe1.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#            features    VIF
# 0                yr  83.86
# 4               hum  39.56
# 3              temp  25.41
# 6     season_Spring   6.70
# 2        workingday   5.81
# 5         windspeed   5.53
# 8     season_Winter   4.77
# 7     season_Summer   3.49
# 13  weathersit_Mist   2.39
# 12      weekday_SAT   2.11
# 9          mnth_JAN   1.72
# 10         mnth_JUL   1.61
# 11         mnth_SEP   1.41
# 14  weathersit_Rain   1.29
# 1           holiday   1.19

# %%
# lm -> Linear Model
lm = LinearRegression()

rfe2 = RFE(estimator=lm, n_features_to_select=7)

# Fitting with 7 best features
rfe2.fit(X_train,y_train)

print(rfe2.ranking_)
print(rfe2.support_)
# Out:
# [ 1  2  8  1  1  1  1  6  3 14 11 12  9  1 21 22 13 10 18  4 16  7 15 19
#  17 20  5  1]
# [ True False False  True  True  True  True False False False False False
#  False  True False False False False False False False False False False
#  False False False  True]

# %%
# Printing Top 7 features of column according to Linear RegressioN Model
col2 = X_train.columns[rfe2.support_]
col2
# Out:
# Index(['yr', 'temp', 'hum', 'windspeed', 'season_Spring', 'mnth_JUL',
#        'weathersit_Rain'],
#       dtype='object')

# %%
X_train_rfe2 = X_train[col2]

X_train_lm = sm.add_constant(X_train_rfe2)
lm2 = sm.OLS(y_train, X_train_lm).fit()
lm2.summary()

# Adj. R Squared -> 81.1%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     312.2
# Date:                Thu, 21 Aug 2025   Prob (F-statistic):          2.34e-178
# Time:                        17:17:52   Log-Likelihood:                 466.35
# No. Observations:                 510   AIC:                            -916.7
# Df Residuals:                     502   BIC:                            -882.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
vif1 = pd.DataFrame()
vif1['features'] = X_train_rfe2.columns
vif1['VIF'] = [variance_inflation_factor(X_train_rfe2.values, i) for i in range(X_train_rfe2.shape[1])]
vif1['VIF'] = round(vif1['VIF'], 2)
vif1 = vif1.sort_values(by = "VIF", ascending = False)
vif1

# Again hum and temp has highest Variance [shows how one feature is simila to all other features in dataset]
# Out:
#           features    VIF
# 0               yr  46.22
# 2              hum  25.50
# 1             temp  12.84
# 3        windspeed   5.20
# 4    season_Spring   2.17
# 5         mnth_JUL   1.35
# 6  weathersit_Rain   1.14

# %%
# Add a constant to X_train_rfe2 before prediction
X_train_rfe2_lm = sm.add_constant(X_train_rfe2)
y_train_cnt = lm2.predict(X_train_rfe2_lm)

# To find how much our model is wrong for each prediction ->
# y_train = actual values (real bike rentals)
# y_train_cnt = predicted values (model’s guesses)

# Subtracting them → Errors  = actual − predicted

# Bins -> When plotting a histogram, we divide the data into intervals which are bins
fig = plt.figure()
sns.distplot(y_train - y_train_cnt, bins = 20)
fig.suptitle('Error Terms', fontsize = 20)
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
# Regenerate df_test from the original dataset
df_train, df_test = train_test_split(dataset, train_size = 0.7, test_size = 0.3, random_state = 100)

# Scaling the test data
var = ["temp" , "hum" , "windspeed" , "casual" , "registered" , "cnt"]
df_test[var] = scaler.transform(df_test[var])

# Separating features and target variable from the test set
y_test = df_test.pop('cnt')
X_test = df_test.drop(['casual' , 'registered'], axis = 1)

# Convert boolean columns to integers in X_test
for col in X_test.columns:
    if X_test[col].dtype == 'bool':
        X_test[col] = X_test[col].astype(int)

# Select the same RFE-selected features from X_test
X_test_rfe2 = X_test[col2]

# Add a constant to X_test_rfe2
X_test_rfe2_lm = sm.add_constant(X_test_rfe2)

# Make predictions on the test set
y_pred = lm2.predict(X_test_rfe2_lm)

# Evaluate the model
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared on the test set: {r2}")

# 80.5 % is R- squared
# Out:
# R-squared on the test set: 0.8052379667299696

# %%
plt.figure()
plt.scatter(y_test,y_pred)

# %%
# Creating Heatmap for 7 Top Features
plt.figure(figsize=(10,10))

sns.heatmap(dataset[col2].corr(),cmap = "YlGnBu" , annot=True)
plt.show()
